# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("/Users/nickolaykrasnenko/Documents/GitHub/SnowFlake/Python_Analysis/Test_hse/data.csv")
df
# Out:
#          rollercoaster_type  excitement excitement_rating  intensity  \
# 0        Bobsleigh Coaster         5.49              High       5.71
# 1              Dinghy Slide        4.83            Medium        NaN
# 2                Wild Mouse        7.64              High       7.86
# 3    Wooden Roller Coaster         7.69              High       7.92
# 4     Junior Roller Coaster        5.17              High        NaN
# ..                      ...         ...               ...        ...
# 137          Spiral Coaster        5.39              High       5.94
# 138         Twister Coaster        7.66              High       6.11
# 139      Mine Train Coaster        7.59              High       7.60
# 140  Wooden Roller Coaster         7.50              High       7.75
# 141            Hypercoaster        6.17              High      44.94
#
#     intensity_rating  nausea nausea_rating  max_speed  ride_time  ride_length
# ...

# %%
(df["intensity"].isna().sum() / 142).round(2)
# Out:
# 0.18

# %%
new = df.groupby("intensity_rating")["nausea"].transform("median")

df["nausea"] = df["nausea"].fillna(new)

round(df["nausea"].std(), 2)
# Out:
# 1.26

# %%
avdf = df["ride_time"].mean()

dfstd = df["ride_time"].std()

first = avdf - dfstd * 1.5
second = avdf + dfstd * 1.5

df[df["ride_time"].between(first, second)]
# Out:
#                rollercoaster_type  excitement excitement_rating  intensity  \
# 0              Bobsleigh Coaster         5.49              High       5.71
# 2                      Wild Mouse        7.64              High       7.86
# 3          Wooden Roller Coaster         7.69              High       7.92
# 5    Side-Friction Roller Coaster        5.68              High       6.18
# 6          Wooden Roller Coaster         7.76         Very High        NaN
# ..                            ...         ...               ...        ...
# 133      Floorless Roller Coaster        7.19              High       9.59
# 134       Stand Up Roller Coaster        5.31              High       8.86
# 136      Corkscrew Roller Coaster        6.14              High       5.88
# 138               Twister Coaster        7.66              High       6.11
# 141                  Hypercoaster        6.17              High      44.94
#
# ...
